# %% [markdown]
# # Tarea #1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataHP = pd.read_csv('./data/train_HP.csv')
dataHP.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
dataHP.shape
# Out:
# (1460, 81)

# %%
dataHP.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Extraemos columnas con NAN

# %%
cols_con_na = [col for col in dataHP.columns if (dataHP[col].isnull().mean() > 0)]

# %%
cols_con_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
dataHP[cols_con_na].dtypes #tipos de dato de las columnas con NANs
# Out:
# LotFrontage     float64
# Alley            object
# MasVnrType       object
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Electrical       object
# FireplaceQu      object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PoolQC           object
# Fence            object
# MiscFeature      object
# dtype: object

# %%
prop_nan_per_col = dataHP[cols_con_na].isnull().mean() #proporcion de nans
prop_nan_per_col
# Out:
# LotFrontage     0.177397
# Alley           0.937671
# MasVnrType      0.005479
# MasVnrArea      0.005479
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# Electrical      0.000685
# FireplaceQu     0.472603
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# PoolQC          0.995205
# Fence           0.807534
# MiscFeature     0.963014
# dtype: float64

# %%
prop_nan_per_col_res = prop_nan_per_col[prop_nan_per_col < 0.2]

# %%
prop_nan_per_col_res
# Out:
# LotFrontage     0.177397
# MasVnrType      0.005479
# MasVnrArea      0.005479
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# Electrical      0.000685
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# dtype: float64

# %%
dataHP[prop_nan_per_col_res.index.to_list()].dtypes
# Out:
# LotFrontage     float64
# MasVnrType       object
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Electrical       object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# dtype: object

# %%
dataset = dataHP[prop_nan_per_col_res.index.to_list()].copy()

# %%
def getColumnTypes(dataset):
    """
    Esta funcion extrae el tipo de dominio de las columnas de un dataset
    Entrada: dataset
    Salida: Tupla con arreglos que cotienen nombres de las columnas
    """

    continuas = []
    discretas = []
    categoricas = []

    for col in dataset.columns:
        if((dataset[col].dtype == 'int64') or (dataset[col].dtype == 'float64')):
            if( len(dataset[col].unique()) > 30):
                continuas.append(col)
            else:
                discretas.append(col)
        else:
            categoricas.append(col)
    return continuas, discretas, categoricas

# %%
continuas, discretas, categoricas = getColumnTypes(dataset)
print(continuas)
print(discretas)
print(categoricas)
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# []
# ['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']

# %% [markdown]
# # Continuas

# %%
def imputacion_continuas(df,column_to_impute):
    media = df[column_to_impute].mean()
    mediana = df[column_to_impute].median()

    df['Mean'] = np.round(df[column_to_impute].fillna(media))
    df['Median'] = np.round(df[column_to_impute].fillna(mediana))
    
    print(f"Media: {media}")
    print(f"Mediana: {mediana}")

    fig = plt.figure()
    df[column_to_impute].plot.density(color='red', label='Original')
    df['Mean'].plot.density(color='blue', label='Media')
    df['Median'].plot.density(color='green', label='Mediana')
    plt.legend()
    
    fig = plt.figure()
    df[[column_to_impute,'Mean','Median']].boxplot()
    plt.show()

# %% [markdown]
# ## LotFrontage

# %%
imputacion_continuas(dataset.copy(), 'LotFrontage')
# Out:
# Media: 70.04995836802665
# Mediana: 69.0

# %% [markdown]
# ## MasVnrArea

# %%
imputacion_continuas(dataset,'MasVnrArea')
# Out:
# Media: 103.68526170798899
# Mediana: 0.0

# %%
dataHP['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %% [markdown]
# MasVnrArea - relacionado tambien con MasVnrType, donde el area nula significa que no hay masonry

# %%
dataHP[['MasVnrArea','MasVnrType']]
# Out:
#       MasVnrArea MasVnrType
# 0          196.0    BrkFace
# 1            0.0       None
# 2          162.0    BrkFace
# 3            0.0       None
# 4          350.0    BrkFace
# ...          ...        ...
# 1455         0.0       None
# 1456       119.0      Stone
# 1457         0.0       None
# 1458         0.0       None
# 1459         0.0       None
#
# [1460 rows x 2 columns]

# %%
dataHP[['MasVnrArea','MasVnrType']].loc[ dataHP['MasVnrType'].isnull()]
# Out:
#       MasVnrArea MasVnrType
# 234          NaN        NaN
# 529          NaN        NaN
# 650          NaN        NaN
# 936          NaN        NaN
# 973          NaN        NaN
# 977          NaN        NaN
# 1243         NaN        NaN
# 1278         NaN        NaN

# %% [markdown]
# ## GarageYrBlt

# %% [markdown]
# Garage - caso especial, la cantidad de nulos coincide con las variables categoricas relacionadas al garage <br>
# los NaNs entonces simplemente existen cuando la cada no tiene garage <br>
# El año la imputación la haré colocando en GarageYrBlt el mismo año de construcción de la casa <br>

# %%
dataHP.loc[dataHP['GarageYrBlt'].isnull(),'GarageYrBlt'] = dataHP['YearBuilt']

# %%
imp_continuas = [
    ('LotFrontage', 'Mean'),
    ('MasVnrArea', 'Median')
]

# %%
def apply_impute_continuous(df, imp_list):
    for var in imp_list:
        if(var[1] == 'Mean'):
            val_impute = df[var[0]].mean()
        else: #Mediana
            val_impute = df[var[0]].median()
        df[var[0]] = np.round(df[var[0]].fillna(val_impute))

# %%
apply_impute_continuous(dataHP, imp_continuas)

# %%
dataHP[continuas].isnull().mean()
# Out:
# LotFrontage    0.0
# MasVnrArea     0.0
# GarageYrBlt    0.0
# dtype: float64

# %% [markdown]
# # Categoricas

# %%
categoricas
# Out:
# ['MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
def imputacion_categoricas(df, column_to_impute, y_col):    
    fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(10, 5))
    
    df[column_to_impute].value_counts().plot.bar(ax=ax1)
    
    values = df[column_to_impute].dropna().unique()
    print(values)
    df.loc[df[column_to_impute].isnull()][y_col].plot(ax=ax2, kind="kde", color="black", label="Missings")
    
    for value in values:
        df[df[column_to_impute] == value][y_col].plot(ax=ax2, kind="kde", label=value)
        
    sns.boxplot(x=df[column_to_impute], y=df[y_col], ax=ax3)
    
    ax2.legend()
    plt.show()

# %% [markdown]
# ## MasVnrType

# %%
dataHP['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
imputacion_categoricas(dataHP.copy(),'MasVnrType','SalePrice')
# Out:
# ['BrkFace' 'None' 'Stone' 'BrkCmn']

# %% [markdown]
# MasVnrType sustituir NaN con None = no hay

# %%
dataHP[['Electrical','SalePrice']].loc[dataHP['Electrical'].isnull()]
# Out:
#      Electrical  SalePrice
# 1379        NaN     167500

# %%
fig, ax = plt.subplots()
sns.barplot(data=dataHP, x='Electrical', y='SalePrice')
# Out:
# <Axes: xlabel='Electrical', ylabel='SalePrice'>

# %% [markdown]
# Para Eletrical es un unico valor NaN <br>
# Sustituyo el valor por el que tiene una media de SalePrice similar a la del precio en esa fila

# %%
basement = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']

# %%
dataHP[basement].isnull().mean()
# Out:
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# dtype: float64

# %%
dataHP['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
dataHP[['BsmtQual', 'BsmtCond', 'BsmtFinType1','BsmtExposure', 'BsmtFinType2']].loc[ dataHP['BsmtQual'].isnull()]
# Out:
#      BsmtQual BsmtCond BsmtFinType1 BsmtExposure BsmtFinType2
# 17        NaN      NaN          NaN          NaN          NaN
# 39        NaN      NaN          NaN          NaN          NaN
# 90        NaN      NaN          NaN          NaN          NaN
# 102       NaN      NaN          NaN          NaN          NaN
# 156       NaN      NaN          NaN          NaN          NaN
# 182       NaN      NaN          NaN          NaN          NaN
# 259       NaN      NaN          NaN          NaN          NaN
# 342       NaN      NaN          NaN          NaN          NaN
# 362       NaN      NaN          NaN          NaN          NaN
# 371       NaN      NaN          NaN          NaN          NaN
# 392       NaN      NaN          NaN          NaN          NaN
# 520       NaN      NaN          NaN          NaN          NaN
# 532       NaN      NaN          NaN          NaN          NaN
# 533       NaN      NaN          NaN          NaN          NaN
# 553       NaN      NaN          NaN          NaN          NaN
# 646       NaN      NaN          NaN          NaN          NaN
# 705       NaN      NaN          NaN          NaN          NaN
# 736       NaN      NaN          NaN          NaN          NaN
# 749       NaN      NaN          NaN          NaN          NaN
# 778       NaN      NaN          NaN          NaN          NaN
# 868       NaN      NaN          NaN          NaN          NaN
# 894       NaN      NaN          NaN          NaN          NaN
# 897       NaN      NaN          NaN          NaN          NaN
# 984       NaN      NaN          NaN          NaN          NaN
# 1000      NaN      NaN          NaN          NaN          NaN
# 1011      NaN      NaN          NaN          NaN          NaN
# 1035      NaN      NaN          NaN          NaN          NaN
# 1045      NaN      NaN          NaN          NaN          NaN
# 1048      NaN      NaN          NaN          NaN          NaN
# 1049      NaN      NaN          NaN          NaN          NaN
# 1090      NaN      NaN          NaN          NaN          NaN
# 1179      NaN      NaN          NaN          NaN          NaN
# 1216      NaN      NaN          NaN          NaN          NaN
# 1218      NaN      NaN          NaN          NaN          NaN
# 1232      NaN      NaN          NaN          NaN          NaN
# 1321      NaN      NaN          NaN          NaN          NaN
# 1412      NaN      NaN          NaN          NaN          NaN

# %%
dataHP[['BsmtExposure', 'BsmtFinType2']].loc[ dataHP['BsmtExposure'].isnull()]
# Out:
#      BsmtExposure BsmtFinType2
# 17            NaN          NaN
# 39            NaN          NaN
# 90            NaN          NaN
# 102           NaN          NaN
# 156           NaN          NaN
# 182           NaN          NaN
# 259           NaN          NaN
# 342           NaN          NaN
# 362           NaN          NaN
# 371           NaN          NaN
# 392           NaN          NaN
# 520           NaN          NaN
# 532           NaN          NaN
# 533           NaN          NaN
# 553           NaN          NaN
# 646           NaN          NaN
# 705           NaN          NaN
# 736           NaN          NaN
# 749           NaN          NaN
# 778           NaN          NaN
# 868           NaN          NaN
# 894           NaN          NaN
# 897           NaN          NaN
# 948           NaN          Unf
# 984           NaN          NaN
# 1000          NaN          NaN
# 1011          NaN          NaN
# 1035          NaN          NaN
# 1045          NaN          NaN
# 1048          NaN          NaN
# 1049          NaN          NaN
# 1090          NaN          NaN
# 1179          NaN          NaN
# 1216          NaN          NaN
# 1218          NaN          NaN
# 1232          NaN          NaN
# 1321          NaN          NaN
# 1412          NaN          NaN

# %% [markdown]
# ## BsmtQual

# %%
imputacion_categoricas(dataHP.copy(),'BsmtQual','SalePrice')
# Out:
# ['Gd' 'TA' 'Ex' 'Fa']

# %%
imputacion_categoricas(dataHP.copy(),'BsmtCond','SalePrice')
# Out:
# ['TA' 'Gd' 'Fa' 'Po']

# %%
imputacion_categoricas(dataHP.copy(),'BsmtExposure','SalePrice')
# Out:
# ['No' 'Gd' 'Mn' 'Av']

# %%
imputacion_categoricas(dataHP.copy(),'BsmtFinType1','SalePrice')
# Out:
# ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'LwQ']

# %%
imputacion_categoricas(dataHP.copy(),'BsmtFinType2','SalePrice')
# Out:
# ['Unf' 'BLQ' 'ALQ' 'Rec' 'LwQ' 'GLQ']

# %% [markdown]
# ## Garage

# %%
garage = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'GarageArea']

# %%
dataHP['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
dataHP['GarageFinish'].unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
dataHP['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %%
dataHP['GarageCond'].unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object)

# %%
dataHP['GarageArea'].describe()
# Out:
# count    1460.000000
# mean      472.980137
# std       213.804841
# min         0.000000
# 25%       334.500000
# 50%       480.000000
# 75%       576.000000
# max      1418.000000
# Name: GarageArea, dtype: float64

# %%
dataHP[garage].loc[ dataHP['GarageArea'] == 0]
# Out:
#      GarageType GarageFinish GarageQual GarageCond  GarageArea
# 39          NaN          NaN        NaN        NaN           0
# 48          NaN          NaN        NaN        NaN           0
# 78          NaN          NaN        NaN        NaN           0
# 88          NaN          NaN        NaN        NaN           0
# 89          NaN          NaN        NaN        NaN           0
# ...         ...          ...        ...        ...         ...
# 1349        NaN          NaN        NaN        NaN           0
# 1407        NaN          NaN        NaN        NaN           0
# 1449        NaN          NaN        NaN        NaN           0
# 1450        NaN          NaN        NaN        NaN           0
# 1453        NaN          NaN        NaN        NaN           0
#
# [81 rows x 5 columns]

# %% [markdown]
# Categoricas donde no hay garage <br>
# Para las variables categoricas, estas tienen NaN cuando el area de garage (variable disponible en el dataset es 0), entonces para estas variables se crea la categoria de "None" como tal en lugar del NaN

# %%
dataHP.loc[dataHP['GarageArea'] == 0, 'GarageType'] = 'None'

# %%
dataHP.loc[dataHP['GarageArea'] == 0, ['GarageType','GarageFinish','GarageQual','GarageCond']] = 'None'

# %%
dataHP[garage].loc[ dataHP['GarageArea'] == 0]
# Out:
#      GarageType GarageFinish GarageQual GarageCond  GarageArea
# 39         None         None       None       None           0
# 48         None         None       None       None           0
# 78         None         None       None       None           0
# 88         None         None       None       None           0
# 89         None         None       None       None           0
# ...         ...          ...        ...        ...         ...
# 1349       None         None       None       None           0
# 1407       None         None       None       None           0
# 1449       None         None       None       None           0
# 1450       None         None       None       None           0
# 1453       None         None       None       None           0
#
# [81 rows x 5 columns]

# %%
dataHP[garage].isnull().mean()
# Out:
# GarageType      0.0
# GarageFinish    0.0
# GarageQual      0.0
# GarageCond      0.0
# GarageArea      0.0
# dtype: float64

# %%
imp_categoricas = [
    ('MasVnrType', 'None'),
    ('Electrical', 'SBrkr'),
    ('BsmtQual', 'TA'),
    ('BsmtCond','Fa'),
    ('BsmtExposure','No'),
    ('BsmtFinType1','Rec'),
    ('BsmtFinType2','BLQ')
]

# %%
def apply_imputacion_categorica(df, cat_app):
    """
    Funcion que aplica las sustituciones enlistadas
    cat_app = lista de duplas con el nombre de la columna y el valor que se le debe colocar a los NaNs
    """
    for cat in cat_app:
        df[cat[0]].fillna(cat[1],inplace=True) #imputacion de variable categorica

# %%
apply_imputacion_categorica(dataHP,imp_categoricas)

# %%
dataHP[cols_con_na].isnull().mean()
# Out:
# LotFrontage     0.000000
# Alley           0.937671
# MasVnrType      0.000000
# MasVnrArea      0.000000
# BsmtQual        0.000000
# BsmtCond        0.000000
# BsmtExposure    0.000000
# BsmtFinType1    0.000000
# BsmtFinType2    0.000000
# Electrical      0.000000
# FireplaceQu     0.472603
# GarageType      0.000000
# GarageYrBlt     0.000000
# GarageFinish    0.000000
# GarageQual      0.000000
# GarageCond      0.000000
# PoolQC          0.995205
# Fence           0.807534
# MiscFeature     0.963014
# dtype: float64

# %%
(dataHP[cols_con_na].isnull().mean() > 0.2)
# Out:
# LotFrontage     False
# Alley            True
# MasVnrType      False
# MasVnrArea      False
# BsmtQual        False
# BsmtCond        False
# BsmtExposure    False
# BsmtFinType1    False
# BsmtFinType2    False
# Electrical      False
# FireplaceQu      True
# GarageType      False
# GarageYrBlt     False
# GarageFinish    False
# GarageQual      False
# GarageCond      False
# PoolQC           True
# Fence            True
# MiscFeature      True
# dtype: bool

# %% [markdown]
# Eliminar columnas con proporcion de nulls arriba del 20%:

# %%
dataHP = dataHP.drop(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'],axis=1)

# %% [markdown]
# # Codificacion de variables categoricas

# %%
def getCategoryVars(dataset):
    cat_colnames = []
    colnames = dataHP.columns
    for col in colnames:
        if(dataHP[col].dtype=='object'):
            cat_colnames.append(col)
    return cat_colnames

# %%
cat_cols = getCategoryVars(dataHP)
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
len(cat_cols)
# Out:
# 38

# %%
for cat in cat_cols:
    uvalues =  dataHP[cat].unique()
    print(f"Variable: {cat} -- values: {uvalues}")
# Out:
# Variable: MSZoning -- values: ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Variable: Street -- values: ['Pave' 'Grvl']
# Variable: LotShape -- values: ['Reg' 'IR1' 'IR2' 'IR3']
# Variable: LandContour -- values: ['Lvl' 'Bnk' 'Low' 'HLS']
# Variable: Utilities -- values: ['AllPub' 'NoSeWa']
# Variable: LotConfig -- values: ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# Variable: LandSlope -- values: ['Gtl' 'Mod' 'Sev']
# Variable: Neighborhood -- values: ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Variable: Condition1 -- values: ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Variable: Condition2 -- values: ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# Variable: BldgType -- values: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# Variable: HouseStyle -- values: ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# Variable: RoofStyle -- values: ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# Variable: RoofMatl -- values: ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
# Variable: Exterior1st -- values: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
# Variable: Exterior2nd -- values: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
# Variable: MasVnrType -- values: ['BrkFace' 'None' 'Stone' 'BrkCmn']
# Variable: ExterQual -- values: ['Gd' 'TA' 'Ex' 'Fa']
# Variable: ExterCond -- values: ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# Variable: Foundation -- values: ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
# Variable: BsmtQual -- values: ['Gd' 'TA' 'Ex' 'Fa']
# Variable: BsmtCond -- values: ['TA' 'Gd' 'Fa' 'Po']
# Variable: BsmtExposure -- values: ['No' 'Gd' 'Mn' 'Av']
# Variable: BsmtFinType1 -- values: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'LwQ']
# Variable: BsmtFinType2 -- values: ['Unf' 'BLQ' 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Variable: Heating -- values: ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
# Variable: HeatingQC -- values: ['Ex' 'Gd' 'TA' 'Fa' 'Po']
# Variable: CentralAir -- values: ['Y' 'N']
# Variable: Electrical -- values: ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
# Variable: KitchenQual -- values: ['Gd' 'TA' 'Ex' 'Fa']
# Variable: Functional -- values: ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
# Variable: GarageType -- values: ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' 'None' 'Basment' '2Types']
# Variable: GarageFinish -- values: ['RFn' 'Unf' 'Fin' 'None']
# Variable: GarageQual -- values: ['TA' 'Fa' 'Gd' 'None' 'Ex' 'Po']
# Variable: GarageCond -- values: ['TA' 'Fa' 'None' 'Gd' 'Po' 'Ex']
# Variable: PavedDrive -- values: ['Y' 'N' 'P']
# Variable: SaleType -- values: ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']
# Variable: SaleCondition -- values: ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']

# %%
#one hot - variables con pocos valores posibles
cat_one_hot = ['Street', 'Utilities', 'LandSlope', 'BsmtExposure', 'CentralAir', 'PavedDrive']

# %%
#freq - variables con mayor cantidad de valores disponibles
cat_freq = [x for x in cat_cols if x not in cat_one_hot]

# %%
cat_freq
# Out:
# ['MSZoning',
#  'LotShape',
#  'LandContour',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'SaleType',
#  'SaleCondition']

# %%
def one_hot_feature(df, feature):
    """
    Funcion para hacer el one hot encoding
    feature = columna sobre la que se debe hacer el one hot encoding
    """
    dummies = pd.get_dummies(df[[feature]])
    dummies.add_prefix(f"{feature}__")
    res = pd.concat([df, dummies], axis=1)
    res = res.drop([feature], axis=1)
    return res

# %%
def freq_encode(df, feature):
    """
    Funcion para hacer el encoding por frecuencia
    feature = columna sobre la que se debe hacer el encoding
    """
    freq_mapper = (df[feature].value_counts().sort_values(ascending=False)).to_dict()
    df[feature] = df[feature].map(freq_mapper)
    return df

# %%
for cat in cat_one_hot:
    dataHP = one_hot_feature(dataHP.copy(), cat)

# %%
for cat in cat_freq:
    dataHP = freq_encode(dataHP.copy(),cat)

# %%
dataHP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 86 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1460 non-null   int64
#  1   MSSubClass        1460 non-null   int64
#  2   MSZoning          1460 non-null   int64
#  3   LotFrontage       1460 non-null   float64
#  4   LotArea           1460 non-null   int64
#  5   LotShape          1460 non-null   int64
#  6   LandContour       1460 non-null   int64
#  7   LotConfig         1460 non-null   int64
#  8   Neighborhood      1460 non-null   int64
#  9   Condition1        1460 non-null   int64
#  10  Condition2        1460 non-null   int64
#  11  BldgType          1460 non-null   int64
#  12  HouseStyle        1460 non-null   int64
#  13  OverallQual       1460 non-null   int64
#  14  OverallCond       1460 non-null   int64
#  15  YearBuilt         1460 non-null   int64
#  16  YearRemodAdd      1460 non-null   int64
#  17  RoofStyle         1460 non-null   int64
#  18  RoofMatl          1460 non-null   int64
#  19  Exterior1st       1460 non-null   int64
#  20  Exterior2nd       1460 non-null   int64
#  21  MasVnrType        1460 non-null   int64
#  22  MasVnrArea        1460 non-null   float64
#  23  ExterQual         1460 non-null   int64
#  24  ExterCond         1460 non-null   int64
#  25  Foundation        1460 non-null   int64
#  26  BsmtQual          1460 non-null   int64
#  27  BsmtCond          1460 non-null   int64
#  28  BsmtFinType1      1460 non-null   int64
#  29  BsmtFinSF1        1460 non-null   int64
#  30  BsmtFinType2      1460 non-null   int64
#  31  BsmtFinSF2        1460 non-null   int64
#  32  BsmtUnfSF         1460 non-null   int64
#  33  TotalBsmtSF       1460 non-null   int64
#  34  Heating           1460 non-null   int64
#  35  HeatingQC         1460 non-null   int64
#  36  Electrical        1460 non-null   int64
#  37  1stFlrSF          1460 non-null   int64
#  38  2ndFlrSF          1460 non-null   int64
#  39  LowQualFinSF      1460 non-null   int64
#  40  GrLivArea         1460 non-null   int64
#  41  BsmtFullBath      1460 non-null   int64
#  42  BsmtHalfBath      1460 non-null   int64
#  43  FullBath          1460 non-null   int64
#  44  HalfBath          1460 non-null   int64
#  45  BedroomAbvGr      1460 non-null   int64
#  46  KitchenAbvGr      1460 non-null   int64
#  47  KitchenQual       1460 non-null   int64
#  48  TotRmsAbvGrd      1460 non-null   int64
#  49  Functional        1460 non-null   int64
#  50  Fireplaces        1460 non-null   int64
#  51  GarageType        1460 non-null   int64
#  52  GarageYrBlt       1460 non-null   float64
#  53  GarageFinish      1460 non-null   int64
#  54  GarageCars        1460 non-null   int64
#  55  GarageArea        1460 non-null   int64
#  56  GarageQual        1460 non-null   int64
#  57  GarageCond        1460 non-null   int64
#  58  WoodDeckSF        1460 non-null   int64
#  59  OpenPorchSF       1460 non-null   int64
#  60  EnclosedPorch     1460 non-null   int64
#  61  3SsnPorch         1460 non-null   int64
#  62  ScreenPorch       1460 non-null   int64
#  63  PoolArea          1460 non-null   int64
#  64  MiscVal           1460 non-null   int64
#  65  MoSold            1460 non-null   int64
#  66  YrSold            1460 non-null   int64
#  67  SaleType          1460 non-null   int64
#  68  SaleCondition     1460 non-null   int64
#  69  SalePrice         1460 non-null   int64
#  70  Street_Grvl       1460 non-null   uint8
#  71  Street_Pave       1460 non-null   uint8
#  72  Utilities_AllPub  1460 non-null   uint8
#  73  Utilities_NoSeWa  1460 non-null   uint8
#  74  LandSlope_Gtl     1460 non-null   uint8
#  75  LandSlope_Mod     1460 non-null   uint8
#  76  LandSlope_Sev     1460 non-null   uint8
#  77  BsmtExposure_Av   1460 non-null   uint8
#  78  BsmtExposure_Gd   1460 non-null   uint8
#  79  BsmtExposure_Mn   1460 non-null   uint8
#  80  BsmtExposure_No   1460 non-null   uint8
#  81  CentralAir_N      1460 non-null   uint8
#  82  CentralAir_Y      1460 non-null   uint8
#  83  PavedDrive_N      1460 non-null   uint8
#  84  PavedDrive_P      1460 non-null   uint8
#  85  PavedDrive_Y      1460 non-null   uint8
# dtypes: float64(3), int64(67), uint8(16)
# memory usage: 821.4 KB
